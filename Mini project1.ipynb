# %%
import random as r
class employee():
    def dep1(self):
        for i in range(1,9):
            fd = r.randint(1,5000)
            print("dep1 ID's  : ",fd)
        if(i>=10):
            print("count matched is :",i,": got 10 or more employee! and validated")                
        else:
            print("count matched is :",i,":it's less than 10 employee! can't validate !")
    def dep2(self):
        for i in range(1,50):
            fd = r.randint(1,5000)
            print("dep2 ID's  : ",fd)
        if(i>=10):
            print("count matched is :",i,": got 10 or more employee! and validated")                
        else:
            print("count matched is :",i,":it's less than 10 employee! can't validate !")
    def dep3(self):
        for i in range(1,25):
            fd = r.randint(1,5000)
            print("dep3 ID's  : ",fd)
        if(i>=10):
            print("count matched is :",i,": got 10 or more employee! and validated")                
        else:
            print("count matched is :",i,":it's less than 10 employee! can't validate !")
    def dep4(self):
        for i in range(1,100):
            fd = r.randint(1,5000)
            print("dep4 ID's  : ",fd)
        if(i>=10):
            print("count matched is :",i,": got 10 or more employee! and validated")                
        else:
            print("count matched is :",i,":it's less than 10 employee! can't validate !")
    def dep5(self):
        for i in range(1,5):
            fd = r.randint(1,5000)
            print("dep5 ID's  : ",fd)
        if(i>=10):
            print("count matched is :",i,": got 10 or more employee! and validated")                
        else:
            print("count matched is :",i,":it's less than 10 employee! can't validate !")

            
f= employee()  
f.dep1()
f.dep2()
f.dep3()
f.dep4()
f.dep5()
# Out:
# dep1 ID's  :  537
# dep1 ID's  :  2839
# dep1 ID's  :  1407
# dep1 ID's  :  4363
# dep1 ID's  :  320
# dep1 ID's  :  2138
# dep1 ID's  :  3494
# dep1 ID's  :  1830
# count matched is : 8 :it's less than 10 employee! can't validate !
# dep2 ID's  :  3518
# dep2 ID's  :  2294
# dep2 ID's  :  3882
# dep2 ID's  :  4109
# dep2 ID's  :  2263
# dep2 ID's  :  3538
# dep2 ID's  :  4723
# dep2 ID's  :  3640
# dep2 ID's  :  4128
# dep2 ID's  :  1946
# dep2 ID's  :  3014
# dep2 ID's  :  4855
# dep2 ID's  :  227
# dep2 ID's  :  3235
# dep2 ID's  :  1371
# dep2 ID's  :  3478
# dep2 ID's  :  2382
# dep2 ID's  :  3350
# dep2 ID's  :  1943
# dep2 ID's  :  1718
# dep2 ID's  :  3144
# dep2 ID's  :  687
# dep2 ID's  :  1958
# dep2 ID's  :  1971
# dep2 ID's  :  2704
# dep2 ID's  :  4798
# dep2 ID's  :  4832
# dep2 ID's  :  3160
# dep2 ID's  :  2498
# dep2 ID's  :  904
# dep2 ID's  :  2969
# dep2 ID's  :  2447
# dep2 ID's  :  1788
# dep2 ID's  :  751
# dep2 ID's  :  1571
# dep2 ID's  :  4527
# dep2 ID's  :  1704
# dep2 ID's  :  1057
# dep2 ID's  :  411
# dep2 ID's  :  4059
# dep2 ID's  :  2435
# dep2 ID's  :  758
# dep2 ID's  :  4775
# dep2 ID's  :  21
# dep2 ID's  :  2954
# dep2 ID's  :  2298
# dep2 ID's  :  2962
# dep2 ID's  :  4558
# dep2 ID's  :  285
# count matched is : 49 : got 10 or more employee! and validated
# dep3 ID's  :  4703
# dep3 ID's  :  3322
# dep3 ID's  :  2006
# dep3 ID's  :  2940
# dep3 ID's  :  3371
# dep3 ID's  :  4009
# dep3 ID's  :  2323
# dep3 ID's  :  1225
# dep3 ID's  :  728
# dep3 ID's  :  1985
# dep3 ID's  :  435
# dep3 ID's  :  2912
# dep3 ID's  :  3113
# dep3 ID's  :  2224
# dep3 ID's  :  493
# dep3 ID's  :  1773
# dep3 ID's  :  1587
# dep3 ID's  :  4863
# dep3 ID's  :  4729
# dep3 ID's  :  4421
# dep3 ID's  :  3758
# dep3 ID's  :  1653
# dep3 ID's  :  4281
# dep3 ID's  :  3882
# count matched is : 24 : got 10 or more employee! and validated
# dep4 ID's  :  2876
# dep4 ID's  :  1615
# dep4 ID's  :  1575
# dep4 ID's  :  786
# dep4 ID's  :  4517
# dep4 ID's  :  4165
# dep4 ID's  :  2025
# dep4 ID's  :  4901
# dep4 ID's  :  430
# dep4 ID's  :  4123
# dep4 ID's  :  4039
# dep4 ID's  :  3801
# dep4 ID's  :  4060
# dep4 ID's  :  3413
# dep4 ID's  :  3088
# dep4 ID's  :  4477
# dep4 ID's  :  4825
# dep4 ID's  :  2100
# dep4 ID's  :  2826
# dep4 ID's  :  3645
# dep4 ID's  :  3460
# dep4 ID's  :  3800
# dep4 ID's  :  1847
# dep4 ID's  :  4116
# dep4 ID's  :  4569
# dep4 ID's  :  2899
# dep4 ID's  :  312
# dep4 ID's  :  598
# dep4 ID's  :  3163
# dep4 ID's  :  1975
# dep4 ID's  :  4284
# dep4 ID's  :  2927
# dep4 ID's  :  2215
# dep4 ID's  :  3292
# dep4 ID's  :  3305
# dep4 ID's  :  2125
# dep4 ID's  :  4941
# dep4 ID's  :  4999
# dep4 ID's  :  3111
# dep4 ID's  :  3155
# dep4 ID's  :  3409
# dep4 ID's  :  1642
# dep4 ID's  :  325
# dep4 ID's  :  4207
# dep4 ID's  :  2431
# dep4 ID's  :  835
# dep4 ID's  :  2692
# dep4 ID's  :  2746
# dep4 ID's  :  1479
# dep4 ID's  :  2690
# dep4 ID's  :  3879
# dep4 ID's  :  1597
# dep4 ID's  :  4443
# dep4 ID's  :  2589
# dep4 ID's  :  1297
# dep4 ID's  :  2133
# dep4 ID's  :  3480
# dep4 ID's  :  475
# dep4 ID's  :  64
# dep4 ID's  :  1356
# dep4 ID's  :  1880
# dep4 ID's  :  2528
# dep4 ID's  :  3807
# dep4 ID's  :  496
# dep4 ID's  :  263
# dep4 ID's  :  1018
# dep4 ID's  :  1816
# dep4 ID's  :  3787
# dep4 ID's  :  2586
# dep4 ID's  :  4120
# dep4 ID's  :  2307
# dep4 ID's  :  4931
# dep4 ID's  :  1298
# dep4 ID's  :  1333
# dep4 ID's  :  2198
# dep4 ID's  :  3675
# dep4 ID's  :  2440
# dep4 ID's  :  2419
# dep4 ID's  :  1832
# dep4 ID's  :  1304
# dep4 ID's  :  878
# dep4 ID's  :  606
# dep4 ID's  :  554
# dep4 ID's  :  4889
# dep4 ID's  :  1412
# dep4 ID's  :  4777
# dep4 ID's  :  3544
# dep4 ID's  :  3985
# dep4 ID's  :  4340
# dep4 ID's  :  2345
# dep4 ID's  :  4540
# dep4 ID's  :  2114
# dep4 ID's  :  2375
# dep4 ID's  :  4959
# dep4 ID's  :  3367
# dep4 ID's  :  2367
# dep4 ID's  :  645
# dep4 ID's  :  3551
# dep4 ID's  :  4844
# count matched is : 99 : got 10 or more employee! and validated
# dep5 ID's  :  3557
# dep5 ID's  :  2501
# dep5 ID's  :  2950
# dep5 ID's  :  2624
# count matched is : 4 :it's less than 10 employee! can't validate !
